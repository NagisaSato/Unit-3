# %% [markdown]
# <a href="https://colab.research.google.com/github/NagisaSato/Unit-3/blob/main/hw.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Vehicle:
    def __init__(self, brand, model, type, speed, weight):
        self.brand = brand
        self.model = model
        self.type = type
        self.gas_tank_size = 14
        self.fuel_level = 0
        self.speed = speed
        self.weight = weight
    def fuel_up(self):
        self.fuel_level = self.gas_tank_size
        print('Gas tank is now full.')

    def drive(self):
        print(f'The {self.model} is now driving.')

    def get_speed(self):
        print(f'The speed is {self.speed}')

    def get_type(self):
        print(f'The type of vehicles is {self.type}')

    def get_weight(self):
        print(f'The weight of vehicles is {self.weight} tonnes')

    def speed_increase(self):
        self.speed *= 1.5

class Truck(Vehicle):
    def __init__(self, brand, model, type, speed, weight):
        super().__init__(brand, model, type, speed, weight)
        self.battery = Battery()
        self.power = power
        self.charge_level = 0
        self.speed=speed
        self.fuel_level = 0
        self.fuel = FuelStorage("Toyata", "654987", "low", "Truck" )

    def charge_truck(self, new_value):
        self.battery.charge_bat(new_value)
        print('The truck is now charged')

    def fuel_up(self):
        print('This truck has no fuel tank.')

    def get_model(self):
        print(f"the model of the truck is {self.model}")

    def get_brand(self):
        print(f"the brand of the truck is {self.brand}")

    def get_fuel_level(self):
        print(f"the current fuel level of the truck is {self.fuel_level}")

    def speed_change(self, new_speed):
        change = self.speed - new_speed
        print(abs(change))

class Battery:
    def __init__(self,brand, model, power, size:int = 20):
        self.size = size
        self.charge_level = 0
        self.brand = brand
        self.model = model
        self.power = power
    def get_charge(self):
        return self.charge_level
    def get_range(self):
        return 10*self.charge_level
    def charge_bat(self, new_value):
        self.charge_level = new_value
    def get_model(self):
        return f"the model of the battery is {self.model}"
    def get_power(self):
        return f"the power of the battery is {self.power}"
    def __repr__(self):
        return f"<This is a battery> size {self.size} charge {self.charge_level}"

vehicle1 = Vehicle('a', 'Model 7564', 'electric ', 76, '2')
my_truck = Truck('Toyota', 'Model 7', 'Truck', 786, '6')
print(my_truck.battery.get_charge())
my_truck.charge_truck(100)
my_truck.battery.charge_bat(80)
print(my_truck.battery.get_charge())

replacement_bat = Battery()
print(replacement_bat.get_charge())


import random
stock_bats = []
for i in range(100):
    a_battery = Battery(size=random.randint(10,100))
    stock_bats.append(a_battery)
    print(a_battery)

for i in range(100):
    stock_bats[i].charge_bat(50)
    print(f"Charge level for battery {i} is {stock_bats[i].get_charge()}")
