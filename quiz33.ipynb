# %% [markdown]
# <a href="https://colab.research.google.com/github/NagisaSato/Unit-3/blob/main/quiz33.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Vehicle:
    def __init__(self, brand, model, type):
        self.brand = brand
        self.model = model
        self.type = type
        self.gas_tank_size = 14
        self.fuel_level = 0

    def fuel_up(self):
        slef.fuel_level = self.gas_tank_size
        print('Gas tank is now full.')

    def drive(self):
        print(f'The {self.model} is now driving.')

class Electric_Vehicles(Vehicle):
    def __init__(self, brand, model, type):
        super().__init__(brand, model, type)
        self.battery = Battery()
        self.charge_level = 0

    def charge_car(self, new_value):
        self.battery.charge_bat(new_value)
        print('The vehicle is now charged')

    def fuel_up(self):
        print('This vehicle has no fuel tank!')

class Battery:
    def __init__(self, size:int = 20):
        self.size = size
        self.charge_level = 0
    def get_charge(self):
        return self.charge_level
    def get_range(self):
        return 10*self.charge_level
    def charge_bat(self, new_value):
        self.charge_level = new_value
    def __repr__(self):
        return f"<This is a battery> size {self.size} charge {self.charge_level}"



#vehicle_object = Vehicle('Honda', 'Ridgeline', 'truck')
my_tesla = Electric_Vehicles('Tesla', 'Model 3', 'Car')
print(my_tesla.battery.get_charge())
my_tesla.charge_car(40)
my_tesla.battery.charge_bat(50)
print(my_tesla.battery.get_charge())

replacement_bat = Battery()
print(replacement_bat.get_charge())


import random
stock_bats = []
for i in range(100):
    a_battery = Battery(size=random.randint(10,100))
    stock_bats.append(a_battery)
    print(a_battery)

# for c in stock_bats:
#     c.charge_bat(50)

for i in range(100):
    stock_bats[i].charge_bat(50)
    print(f"Charge level for battery {i} is {stock_bats[i].get_charge()}")
# Out:
# 0
# The vehicle is now charged
# 50
# 0
# <This is a battery> size 34 charge 0
# <This is a battery> size 45 charge 0
# <This is a battery> size 73 charge 0
# <This is a battery> size 39 charge 0
# <This is a battery> size 41 charge 0
# <This is a battery> size 84 charge 0
# <This is a battery> size 33 charge 0
# <This is a battery> size 28 charge 0
# <This is a battery> size 15 charge 0
# <This is a battery> size 40 charge 0
# <This is a battery> size 57 charge 0
# <This is a battery> size 11 charge 0
# <This is a battery> size 38 charge 0
# <This is a battery> size 43 charge 0
# <This is a battery> size 72 charge 0
# <This is a battery> size 15 charge 0
# <This is a battery> size 43 charge 0
# <This is a battery> size 58 charge 0
# <This is a battery> size 12 charge 0
# <This is a battery> size 67 charge 0
# <This is a battery> size 97 charge 0
# <This is a battery> size 28 charge 0
# <This is a battery> size 100 charge 0
# <This is a battery> size 59 charge 0
# <This is a battery> size 28 charge 0
# <This is a battery> size 20 charge 0
# <This is a battery> size 36 charge 0
# <This is a battery> size 57 charge 0
# <This is a battery> size 74 charge 0
# <This is a battery> size 79 charge 0
# <This is a battery> size 66 charge 0
# <This is a battery> size 49 charge 0
# <This is a battery> size 16 charge 0
# <This is a battery> size 32 charge 0
# <This is a battery> size 28 charge 0
# <This is a battery> size 23 charge 0
# <This is a battery> size 93 charge 0
# <This is a battery> size 84 charge 0
# <This is a battery> size 95 charge 0
# <This is a battery> size 61 charge 0
# <This is a battery> size 30 charge 0
# <This is a battery> size 17 charge 0
# <This is a battery> size 47 charge 0
# <This is a battery> size 23 charge 0
# <This is a battery> size 10 charge 0
# <This is a battery> size 31 charge 0
# <This is a battery> size 57 charge 0
# <This is a battery> size 58 charge 0
# <This is a battery> size 69 charge 0
# <This is a battery> size 65 charge 0
# <This is a battery> size 62 charge 0
# <This is a battery> size 67 charge 0
# <This is a battery> size 94 charge 0
# <This is a battery> size 59 charge 0
# <This is a battery> size 84 charge 0
# <This is a battery> size 10 charge 0
# <This is a battery> size 87 charge 0
# <This is a battery> size 82 charge 0
# <This is a battery> size 87 charge 0
# <This is a battery> size 93 charge 0
# <This is a battery> size 78 charge 0
# <This is a battery> size 57 charge 0
# <This is a battery> size 100 charge 0
# <This is a battery> size 87 charge 0
# <This is a battery> size 49 charge 0
# <This is a battery> size 46 charge 0
# <This is a battery> size 71 charge 0
# <This is a battery> size 51 charge 0
# <This is a battery> size 45 charge 0
# <This is a battery> size 44 charge 0
# <This is a battery> size 82 charge 0
# <This is a battery> size 82 charge 0
# <This is a battery> size 65 charge 0
# <This is a battery> size 54 charge 0
# <This is a battery> size 46 charge 0
# <This is a battery> size 78 charge 0
# <This is a battery> size 30 charge 0
# <This is a battery> size 74 charge 0
# <This is a battery> size 96 charge 0
# <This is a battery> size 68 charge 0
# <This is a battery> size 87 charge 0
# <This is a battery> size 47 charge 0
# <This is a battery> size 72 charge 0
# <This is a battery> size 63 charge 0
# <This is a battery> size 58 charge 0
# <This is a battery> size 51 charge 0
# <This is a battery> size 16 charge 0
# <This is a battery> size 64 charge 0
# <This is a battery> size 79 charge 0
# <This is a battery> size 15 charge 0
# <This is a battery> size 25 charge 0
# <This is a battery> size 98 charge 0
# <This is a battery> size 39 charge 0
# <This is a battery> size 61 charge 0
# <This is a battery> size 13 charge 0
# <This is a battery> size 85 charge 0
# <This is a battery> size 98 charge 0
# <This is a battery> size 29 charge 0
# <This is a battery> size 72 charge 0
# <This is a battery> size 35 charge 0
# Charge level for battery 0 is 50
# Charge level for battery 1 is 50
# Charge level for battery 2 is 50
# Charge level for battery 3 is 50
# Charge level for battery 4 is 50
# Charge level for battery 5 is 50
# Charge level for battery 6 is 50
# Charge level for battery 7 is 50
# Charge level for battery 8 is 50
# Charge level for battery 9 is 50
# Charge level for battery 10 is 50
# Charge level for battery 11 is 50
# Charge level for battery 12 is 50
# Charge level for battery 13 is 50
# Charge level for battery 14 is 50
# Charge level for battery 15 is 50
# Charge level for battery 16 is 50
# Charge level for battery 17 is 50
# Charge level for battery 18 is 50
# Charge level for battery 19 is 50
# Charge level for battery 20 is 50
# Charge level for battery 21 is 50
# Charge level for battery 22 is 50
# Charge level for battery 23 is 50
# Charge level for battery 24 is 50
# Charge level for battery 25 is 50
# Charge level for battery 26 is 50
# Charge level for battery 27 is 50
# Charge level for battery 28 is 50
# Charge level for battery 29 is 50
# Charge level for battery 30 is 50
# Charge level for battery 31 is 50
# Charge level for battery 32 is 50
# Charge level for battery 33 is 50
# Charge level for battery 34 is 50
# Charge level for battery 35 is 50
# Charge level for battery 36 is 50
# Charge level for battery 37 is 50
# Charge level for battery 38 is 50
# Charge level for battery 39 is 50
# Charge level for battery 40 is 50
# Charge level for battery 41 is 50
# Charge level for battery 42 is 50
# Charge level for battery 43 is 50
# Charge level for battery 44 is 50
# Charge level for battery 45 is 50
# Charge level for battery 46 is 50
# Charge level for battery 47 is 50
# Charge level for battery 48 is 50
# Charge level for battery 49 is 50
# Charge level for battery 50 is 50
# Charge level for battery 51 is 50
# Charge level for battery 52 is 50
# Charge level for battery 53 is 50
# Charge level for battery 54 is 50
# Charge level for battery 55 is 50
# Charge level for battery 56 is 50
# Charge level for battery 57 is 50
# Charge level for battery 58 is 50
# Charge level for battery 59 is 50
# Charge level for battery 60 is 50
# Charge level for battery 61 is 50
# Charge level for battery 62 is 50
# Charge level for battery 63 is 50
# Charge level for battery 64 is 50
# Charge level for battery 65 is 50
# Charge level for battery 66 is 50
# Charge level for battery 67 is 50
# Charge level for battery 68 is 50
# Charge level for battery 69 is 50
# Charge level for battery 70 is 50
# Charge level for battery 71 is 50
# Charge level for battery 72 is 50
# Charge level for battery 73 is 50
# Charge level for battery 74 is 50
# Charge level for battery 75 is 50
# Charge level for battery 76 is 50
# Charge level for battery 77 is 50
# Charge level for battery 78 is 50
# Charge level for battery 79 is 50
# Charge level for battery 80 is 50
# Charge level for battery 81 is 50
# Charge level for battery 82 is 50
# Charge level for battery 83 is 50
# Charge level for battery 84 is 50
# Charge level for battery 85 is 50
# Charge level for battery 86 is 50
# Charge level for battery 87 is 50
# Charge level for battery 88 is 50
# Charge level for battery 89 is 50
# Charge level for battery 90 is 50
# Charge level for battery 91 is 50
# Charge level for battery 92 is 50
# Charge level for battery 93 is 50
# Charge level for battery 94 is 50
# Charge level for battery 95 is 50
# Charge level for battery 96 is 50
# Charge level for battery 97 is 50
# Charge level for battery 98 is 50
# Charge level for battery 99 is 50
